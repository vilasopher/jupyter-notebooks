# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
multinomial = lambda xs : np.math.factorial(np.sum(xs)) / np.product([np.math.factorial(x) for x in xs])

# %%
n = 50
c = lambda eps : np.sum([
        np.sum([
            multinomial([k,k,j,n-2*k-j]) * (-2)**j * eps**(j+2*k) for j in range(n-2*k+1)
        ], axis=-1) for k in range(n+1) ], axis=-1)
p = lambda eps : (1-eps)**n

# %%
es = 1/np.sqrt(n) * np.arange(0,1,0.01)
cs = np.array(c(x) for x in)

# %%
c(np.array([1,2]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-4db925c2445a> in <module>
# ----> 1 c(np.array([1,2]))
#
# <ipython-input-13-578a3b367c6f> in <lambda>(eps)
#       1 n = 50
# ----> 2 c = lambda eps : np.sum([
#       3         np.sum([
#       4             multinomial([k,k,j,n-2*k-j]) * (-2)**j * eps**(j+2*k) for j in range(n-2*k+1)
#       5         ], axis=-1) for k in range(n+1) ], axis=-1)
#
# ~/lib/python3.10/site-packages/numpy/core/overrides.py in sum(*args, **kwargs)
#
# ~/lib/python3.10/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2322         return res
#    2323
# -> 2324     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2325                           initial=initial, where=where)
#    2326
#
# ...

# %%
c(0.1)
# Out:
# 1.3775624456268525e+21
