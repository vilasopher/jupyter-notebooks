# %%
from p5 import *

def setup():
    size(640, 360)
    no_stroke()
    background(204)

def draw():
    if mouse_is_pressed:
        fill(random_uniform(255), random_uniform(127), random_uniform(51), 127)
    else:
        fill(255, 15)

    circle_size = random_uniform(low=10, high=80)

    circle((mouse_x, mouse_y), circle_size)

def key_pressed(event):
    background(204)

# p5 supports different backends to render sketches,
# "vispy" for both 2D and 3D sketches & "skia" for 2D sketches
# use "skia" for better 2D experience
# Default renderer is set to "vispy"
run(renderer="vispy") # "skia" is still in beta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-45f9cba893a9> in <module>
# ----> 1 from p5 import *
#       2
#       3 def setup():
#       4     size(640, 360)
#       5     no_stroke()
#
# /var/mobile/Containers/Data/Application/F9ECFC51-8DF8-4172-B191-4C4E6122BD67/Documents/site-packages/p5/__init__.py in <module>
#      17 #
#      18
# ---> 19 from .sketch import *
#      20 from .core import *
#      21 from .pmath import *
#
# /var/mobile/Containers/Data/Application/F9ECFC51-8DF8-4172-B191-4C4E6122BD67/Documents/site-packages/p5/sketch/__init__.py in <module>
#      16 # along with this program. If not, see <http://www.gnu.org/licenses/>.
#      17 #
# ---> 18 from .userspace import *
#      19 from .api import *
#
# /var/mobile/Containers/Data/Application/F9ECFC51-8DF8-4172-B191-4C4E6122BD67/Documents/site-packages/p5/sketch/userspace.py in <module>
#      30 from .events import handler_names
#      31
# ---> 32 from ..core import p5
#      33 from ..pmath import matrix
#      34
#
# /var/mobile/Containers/Data/Application/F9ECFC51-8DF8-4172-B191-4C4E6122BD67/Documents/site-packages/p5/core/__init__.py in <module>
#      16 # along with this program. If not, see <http://www.gnu.org/licenses/>.
#      17 #
# ---> 18 from .structure import *
#      19 from .primitives import *
#      20 from .primitives3d import *
#
# /var/mobile/Containers/Data/Application/F9ECFC51-8DF8-4172-B191-4C4E6122BD67/Documents/site-packages/p5/core/structure.py in <module>
#      19 from copy import deepcopy
#      20
# ---> 21 from . import p5
#      22
#      23 from contextlib import AbstractContextManager
#
# /var/mobile/Containers/Data/Application/F9ECFC51-8DF8-4172-B191-4C4E6122BD67/Documents/site-packages/p5/core/p5.py in <module>
#      19 """Environment Variables for P5 sketches"""
#      20
# ---> 21 from .tess import Tessellator
#      22
#      23 sketch = None
#
# /var/mobile/Containers/Data/Application/F9ECFC51-8DF8-4172-B191-4C4E6122BD67/Documents/site-packages/p5/core/tess.py in <module>
# ----> 1 from OpenGL.GLU import (
#       2     gluNewTess,
#       3     gluTessCallback,
#       4     GLU_TESS_VERTEX,
#       5     GLU_TESS_BEGIN,
#
# ModuleNotFoundError: No module named 'OpenGL'
